# %%
lastLine = ''
Output = ''
index = 1
with open('Movie.csv',encoding="utf-8") as file:
    with open('movieFinal.csv', 'a') as movieFile:
        movieFile.truncate(0)
        for i,line in enumerate(file.readlines()):
            if '|' not in line:
                Output += line.replace('\n', '')
            else:
                lastLine = line.split(" | ")
                if lastLine[1] == ' ':
                    astLine[1] == 'NA'
                lastLine[3] = lastLine[3].replace('\n', '')
                for i in range(0, 4):
                    if i == 3:
                        lastLine[i].replace("…", '')
                        Output += str(lastLine[i]).replace('\t', '')
                    else:
                        if i == 0:
                            Output += "\n"
                        Output += str(lastLine[i]) + " | "
                
                movieFile.write(Output)
                
                index += 1
                Output = ''
                
    print("End")
# Out:
# End
